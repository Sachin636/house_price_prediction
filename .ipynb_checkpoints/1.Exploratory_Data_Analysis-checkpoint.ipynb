# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
train = pd.read_csv('./Data/train.csv')
test = pd.read_csv('./Data/test.csv')

# %% [markdown]
# # 1. Exploratory Data Analysis

# %% [markdown]
# Categorical and Numerical variables

# %%
numeric = train.select_dtypes(exclude="object")
categorical = train.select_dtypes(include="object")
print("# of Numeric Variables : ", len(numeric.columns))
print("# of Categorical Variables : ", len(categorical.columns))
# Out:
# # of Numeric Variables :  38
# # of Categorical Variables :  43

# %% [markdown]
# Numeric Variables are :

# %%
print(list(numeric.columns))
# Out:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %% [markdown]
# Categorical variables are :

# %%
print(list(categorical.columns))
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %% [markdown]
# ### Analysing Sale Price

# %% [markdown]
# Let's take a quick look at Sale Price.

# %%
train["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(train["SalePrice"]).set_title('Distribution of Sale Price')
# Out:
# Text(0.5, 1.0, 'Distribution of Sale Price')

# %%
sns.boxplot(x = train["SalePrice"]).set_title("Box plot of Sale Price")
# Out:
# Text(0.5, 1.0, 'Box plot of Sale Price')

# %% [markdown]
# Looks like Sale Price is right skewed.But the minimum value is not zero and there is no missing value, So we can proceed with our data analysis.

# %% [markdown]
# ### Correlation of numeric values

# %%
corrmat = train.corr()
values = corrmat.iloc[:,-1:]
values = values.sort_values(by = ['SalePrice'],ascending = False)
values = values.iloc[1:16]
cm = sns.light_palette("blue", as_cmap=True)
s = values.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow0_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow1_col0 {
#             background-color:  #2b2bff;
#             color:  #f1f1f1;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow2_col0 {
#             background-color:  #4e4eff;
#             color:  #f1f1f1;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow3_col0 {
#             background-color:  #5757ff;
#             color:  #f1f1f1;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow4_col0 {
#             background-color:  #5d5dff;
#             color:  #000000;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow5_col0 {
#             background-color:  #6060ff;
#             color:  #000000;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow6_col0 {
#             background-color:  #7979ff;
#             color:  #000000;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow7_col0 {
#             background-color:  #8686ff;
#             color:  #000000;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow8_col0 {
#             background-color:  #8c8cff;
#             color:  #000000;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow9_col0 {
#             background-color:  #9494ff;
#             color:  #000000;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow10_col0 {
#             background-color:  #9f9fff;
#             color:  #000000;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow11_col0 {
#             background-color:  #a4a4ff;
#             color:  #000000;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow12_col0 {
#             background-color:  #a9a9ff;
#             color:  #000000;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow13_col0 {
#             background-color:  #d3d3ff;
#             color:  #000000;
#         }    #T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow14_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }</style><table id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SalePrice</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row0" class="row_heading level0 row0" >OverallQual</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow0_col0" class="data row0 col0" >0.790982</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row1" class="row_heading level0 row1" >GrLivArea</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow1_col0" class="data row1 col0" >0.708624</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row2" class="row_heading level0 row2" >GarageCars</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow2_col0" class="data row2 col0" >0.640409</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row3" class="row_heading level0 row3" >GarageArea</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow3_col0" class="data row3 col0" >0.623431</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row4" class="row_heading level0 row4" >TotalBsmtSF</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow4_col0" class="data row4 col0" >0.613581</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row5" class="row_heading level0 row5" >1stFlrSF</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow5_col0" class="data row5 col0" >0.605852</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row6" class="row_heading level0 row6" >FullBath</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow6_col0" class="data row6 col0" >0.560664</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row7" class="row_heading level0 row7" >TotRmsAbvGrd</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow7_col0" class="data row7 col0" >0.533723</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row8" class="row_heading level0 row8" >YearBuilt</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow8_col0" class="data row8 col0" >0.522897</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row9" class="row_heading level0 row9" >YearRemodAdd</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow9_col0" class="data row9 col0" >0.507101</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row10" class="row_heading level0 row10" >GarageYrBlt</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow10_col0" class="data row10 col0" >0.486362</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row11" class="row_heading level0 row11" >MasVnrArea</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow11_col0" class="data row11 col0" >0.477493</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row12" class="row_heading level0 row12" >Fireplaces</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow12_col0" class="data row12 col0" >0.466929</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row13" class="row_heading level0 row13" >BsmtFinSF1</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow13_col0" class="data row13 col0" >0.38642</td>
#             </tr>
#             <tr>
#                         <th id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840elevel0_row14" class="row_heading level0 row14" >LotFrontage</th>
#                         <td id="T_8f37d992_2e74_11eb_9bfe_80c5f21e840erow14_col0" class="data row14 col0" >0.351799</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Above table shows the top 15 highest correlated numerical variables.

# %% [markdown]
# #### Overall quality Vs Sale price

# %%
var = 'OverallQual'
data = pd.concat([train['SalePrice'], train[y_val]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=700000);

# %% [markdown]
# #### Ground living area Vs Sale price

# %%
plt.figure(figsize=(10,6))
var = 'GrLivArea'
plt.scatter(x = train[var],y = train['SalePrice'],color='green',alpha = 0.4)
plt.title("Ground living Area Vs Sale price")
plt.xlabel('Ground living Area(sq.foot)')
plt.ylabel('Sale Price')
plt.show()

# %% [markdown]
# There is a linear relationship between Sale Price and the Ground Living Area.

# %%
plt.figure(figsize=(10,6)).title('Garage cars Vs Sale Price')
var = 'GarageCars'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=700000);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-659e6656c723> in <module>
#       4 f, ax = plt.subplots(figsize=(8, 6))
#       5 fig = sns.boxplot(x=var, y="SalePrice", data=data).set_title('Garage cars Vs Sale Price')
# ----> 6 fig.axis(ymin=0, ymax=700000);
#
# AttributeError: 'Text' object has no attribute 'axis'
